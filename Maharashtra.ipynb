# %%
import pandas as pd

# %%
df=pd.read_html("https://coronaclusters.in/maharashtra")

# %%
df1=pd.DataFrame(df[0])

# %%
df1.drop("Last Updated",axis=1,inplace=True)

# %%
df1
# Out:
#        District  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0          Pune          781          0            36           0
# 1        Mumbai         3227          0            33           0
# 2        Nagpur          131          0             4           0
# 3    Ahmednagar           56          0             2           0
# 4         Thane          466          0            17           0
# 5        Raigad           93          0             7           0
# 6      Yavatmal           39          0             0           0
# 7    Aurangabad           93          0            20           0
# 8     Ratnagiri           33          0             2           0
# 9       Palghar          142          0             8           0
# 10       Sangli           53          0             0           0
# 11       Satara           54          0             2           0
# 12   Sindhudurg           15          0             2           0
# ...
